# %% [markdown]
# # Logging
# (back to the overview [offline](../Main.ipynb),[online](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/Main.ipynb))
#
# [read on nbviewer](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/logging/logging_example.ipynb)

# %% [markdown]
# ## TL;DR
#  * There is a QCoDeS logging module: `qcodes.utils.logger`
#  * Call `logger.start_all_logging` at the start of every script/session to make sure all log messages get stored to the `.qcodes/logs` folder in your home directory.
#  * For debugging purposes you can log messages of an individual instrument (and see the VISA dialog).
#  * You can obtain all logging messages in a `pandas.DataFrame` for further analysis.

# %% [markdown]
# ## Contents
# - [Introduction](#Introduction)
# - [Set up logging in QCoDeS](#Set-up-logging-in-QCoDeS)
#   - [QCoDeS default handlers](#QCoDeS-default-handlers)
#   - [IPython command history](#IPython-command-history)
# - [Temporarily elevating the logging level](#Temporarily-elevating-the-logging-level)
# - [Filtering log messages by instrument](#Filtering-log-messages-by-instrument)
# - [Capturing Pandas.DataFrame](#Capturing-Pandas.DataFrame)

# %% [markdown]
# ## Introduction
# Python offers an excellent logging framework that is widely used in QCoDeS. As a user you might be interested in reading the log messages that are generated by QCoDeS for debugging and also profiling purposes.
#
# All log records(=messages+meta data) are created using a python `logging.logger` object. In QCoDeS there is a logger for every module with the same name as the module itself, i.e. you can use `logging.getLogger('qcodes.instrument.base')` for getting the logger of the QCoDeS `Instrument`. From the dots in the names of the loggers a hierarchy is define, at the top of which is the so called *root logger* that catches all messages.
# The log records created in a logger are processed by the *handlers* that have been attached to this specific *logger*.
# The handlers can for example be used to output the log messages into different locations, like the console or a log file.
#
# Every logger, handler and log record has an associated level. The default levels are: `CRITICAL` `ERROR`, `WARNING`, `INFO`, `DEBUG`. The levels determine how messages are passed: A logger passes only records that exceeds its minimal passing level to its handlers and the handlers in turn only output those messages that exceed their minimal passing level.
#
#
# For a more detailed description of Python logging refer to the [official manual](https://docs.python.org/3.6/library/logging.html#module-logging) (This is all well summed up [in this chart](https://docs.python.org/3.6/howto/logging.html#logging-flow))

# %% [markdown]
# ## Instrument communication loggers
# Not all the used loggers in QCoDeS follow the previously presented rule of naming the logger after the module. For instruments there are the following loggers:
#  - **qcodes.instrument.base.com**:
#    This logger logs all the communication of the `Instrument` and its descendants with the actual physical instruments e.g. the messages generated by the `write` and `query` calls.
#  - **qcodes.instrument.base.com.visa**:
#   This is a sublogger that logs all the communication related messages of the `VisaInstrument` and its descendants.

# %% [markdown]
# ## Set up logging in QCoDeS
# At the beginning of every experiment script file you should include the following lines:

# %%
from qcodes.logger import start_all_logging
start_all_logging()
# Out:
# 2018-10-22 16:55:38,614 ¦ qcodes.logger.logger ¦ INFO ¦ logger ¦ start_logger ¦ 163 ¦ QCoDes logger setup completed
# 2018-10-22 16:55:38,624 ¦ qcodes.logger.logger ¦ INFO ¦ logger ¦ start_command_history_logger ¦ 187 ¦ Started logging IPython history
# Logging hadn't been started.
# Activating auto-logging. Current session state plus future input saved.
# Filename       : C:\Users\a-dovoge\.qcodes\logs\command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active

# %% [markdown]
# The call to `start_all_logging` does two things:
# 1. Create handlers to output logging messages from the root logger to the console and to a log file.
# 2. Enable logging of the ipython commands into a separate log file.

# %% [markdown]
# ### QCoDeS default handlers
# The effect of the console handler can be seen in the two printed lines with a red background below the previous code cell. Every line corresponds to a log record. The fields of the records are separated by `¦` and have the following meaning:
#  0. time stamp
#  1. logger name, here the module name
#  2. record log level
#  3. name of the function that created the log message
#  4. line at which the message has been issued
#  5. actual log message
#
# The same format is used for the file handler. By default QCoDeS logs to the file `<user directory>/.qcodes/logs/qcodes.log`. To avoid endlessly long files, the files roll over at midnight and get the date appended to their name where `qcodes.log` without date always gives you the log messages of the same day.
#
# To configure the levels you want to log/handle, you need to edit the `qcodesrc.json` file in you home directory. The default values are:
# ```
#     "logger":{
#         "console_level": "WARNING",
#         "file_level": "INFO",
#         "logger_levels":{
#             "pyvisa": "INFO"
#         }
# ```
# While `console_level` and `file_level` describe the levels of the two default handlers described previously, `logger_levels` is a dictionary that can be used to limit the messages passed on by module level loggers. This means with these defaults, the pyvisa module will not log messages on a `DEBUG` level. Therefore setting the `console_level` to `DEBUG` will not show the pyvisa debug messages (you certainly don't want to see them as they log every single character that is passed to an instrument with an individual message). On the other hand setting the console level to warning will still suppress pyvisa info messages.

# %% [markdown]
# ### IPython command history
# The output above that follows these logging messages comes from IPython. It tells us that all issued IPython commands will be logged to a file. The file lives in the same log directory as the python logs and is called `command_history.log`. It will not roll over.
#
# To change the command history logging directory you will need to call `start_command_history_logger` with the new path as an argument.

# %% [markdown]
# ## Temporarily elevating the logging level
# Sometimes you might wish to catch e.g. all debug messages for a few lines of code. You can do this simply by:

# %%
import logging
import qcodes.logger as logger
log = logging.getLogger('example_logger')

log.debug('This message will not be visible as the logging level is set to `DEBUG`')

with logger.console_level(logging.DEBUG):
    log.debug('This message is visible as the logging level is temporarily elevated to `DEBUG`')
    
log.debug('The level is back to what it used to be')
# Out:
# 2018-10-22 16:55:41,589 ¦ example_logger ¦ DEBUG ¦ <ipython-input-2-c7e8205cb86b> ¦ <module> ¦ 8 ¦ This message is visible as the logging level is temporarily elevated to `DEBUG`

# %% [markdown]
# For other handlers than the console handler you can do the same thing using the `handler_level` context manager.

# %% [markdown]
# ## Filtering log messages by instrument
# A very common use case for logging in qcodes is to analyze the communication with a VISA instrument. For this purpose the logger module provides a context manager to filter the logging messages by instrument.
#
# Generally one could of course simply attach a handler to the logger of `qcodes.instrument_drivers.Vendor.Type` but this would not show the messages that are generated by the visa communication in `qcodes.instrument.visa`. Additionally with the approach implemented here one can not only filter messages for a given type of instrument but also of a specific instance.
#
# To demonstrate this consider the following mock up of the AMI430 Magnet controller that consists of individual visa instruments for each axis, here with the names `x`, `y` and `z`:

# %%
from qcodes.instrument.ip_to_visa import AMI430_VISA
from qcodes.instrument_drivers.american_magnetics.AMI430 import AMI430_3D, AMI430Warning

import qcodes.instrument.sims as sims

visalib = sims.__file__.replace('__init__.py', 'AMI430.yaml@sim')

mag_x = AMI430_VISA('x', address='GPIB::1::INSTR', visalib=visalib,
                        terminator='\n', port=1)
mag_y = AMI430_VISA('y', address='GPIB::2::INSTR', visalib=visalib,
                        terminator='\n', port=1)
mag_z = AMI430_VISA('z', address='GPIB::3::INSTR', visalib=visalib,
                        terminator='\n', port=1)

import numpy as np
field_limit = [
    lambda x, y, z: x == 0 and y == 0 and z < 3,
    lambda x, y, z: np.linalg.norm([x, y, z]) < 2
]

driver = AMI430_3D("AMI430-3D", mag_x, mag_y, mag_z, field_limit)
# Out:
# 2018-10-22 16:55:43,235 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 115 ¦ [x(AMI430_VISA)] Opening PyVISA Resource Manager with visalib: c:\users\a-dovoge\qcodes\qcodes\instrument\sims\AMI430.yaml@sim
# 2018-10-22 16:55:43,450 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 124 ¦ [x(AMI430_VISA)] Opening PyVISA resource at address: GPIB::1::INSTR
# 2018-10-22 16:55:43,462 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 115 ¦ [y(AMI430_VISA)] Opening PyVISA Resource Manager with visalib: c:\users\a-dovoge\qcodes\qcodes\instrument\sims\AMI430.yaml@sim
# 2018-10-22 16:55:43,464 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 124 ¦ [y(AMI430_VISA)] Opening PyVISA resource at address: GPIB::2::INSTR
# 2018-10-22 16:55:43,476 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 115 ¦ [z(AMI430_VISA)] Opening PyVISA Resource Manager with visalib: c:\users\a-dovoge\qcodes\qcodes\instrument\sims\AMI430.yaml@sim
# 2018-10-22 16:55:43,478 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 124 ¦ [z(AMI430_VISA)] Opening PyVISA resource at address: GPIB::3::INSTR
# Connected to: QCoDeS AMI430_simulation (serial:1337, firmware:0.0.01) in 0.23s
# Connected to: QCoDeS AMI430_simulation (serial:1337, firmware:0.0.01) in 0.01s
# Connected to: QCoDeS AMI430_simulation (serial:1337, firmware:0.0.01) in 0.02s

# %% [markdown]
# In the above messages you can see the prefix `[<instrument_name>(<instrument_type>)]`. To analyze the visa communication one can use `filter_instrument`:

# %%
driver.cartesian((0, 0, 0))
with logger.console_level('DEBUG'):
    with logger.filter_instrument(mag_x):
        driver.cartesian((0, 0, 1))
# Out:
# 2018-10-22 16:55:44,671 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ [x(AMI430_VISA)] Querying: STATE?
# 2018-10-22 16:55:44,672 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ [x(AMI430_VISA)] Response: 2
# 2018-10-22 16:55:44,674 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-22 16:55:44,676 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ [x(AMI430_VISA)] Response: 0
# 2018-10-22 16:55:44,679 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-22 16:55:44,680 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ [x(AMI430_VISA)] Response: 0

# %% [markdown]
# The output on the console shows as expected only messages from the `x` instrument. For multiple instruments pass a sequence of instruments to `filter_instrument`:

# %%
driver.cartesian((0, 0, 0))
with logger.console_level('DEBUG'):
    with logger.filter_instrument((mag_x, mag_y)):
        driver.cartesian((0, 0, 1))
# Out:
# 2018-10-22 16:55:45,965 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ [x(AMI430_VISA)] Querying: STATE?
# 2018-10-22 16:55:45,967 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ [x(AMI430_VISA)] Response: 2
# 2018-10-22 16:55:45,969 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ [y(AMI430_VISA)] Querying: STATE?
# 2018-10-22 16:55:45,970 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ [y(AMI430_VISA)] Response: 2
# 2018-10-22 16:55:45,972 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-22 16:55:45,973 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ [x(AMI430_VISA)] Response: 0
# 2018-10-22 16:55:45,975 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ [y(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-22 16:55:45,977 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ [y(AMI430_VISA)] Response: 0
# 2018-10-22 16:55:45,979 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-22 16:55:45,980 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ [x(AMI430_VISA)] Response: 0
# 2018-10-22 16:55:45,982 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ [y(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-22 16:55:45,983 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ [y(AMI430_VISA)] Response: 0

# %% [markdown]
# ## Capturing Pandas.DataFrame
# To process the logs, especially with the timestamps the [pandas module](https://pandas.pydata.org/) is highly suited. With `logger.log_to_dataframe` or `logger.logfile_to_dataframe` you can convert a log(file) to a pandas `DataFrame`. See this ([online](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/logging/logfile_parsing.ipynb), [offline](logfile_parsing.ipynb)) notebook for an example.
#
# You can also use a context manager to capture the logs directly into a `DataFrame`

# %%
with logger.console_level(logging.WARN):
    driver.cartesian((0, 0, 0))
    with logger.capture_dataframe(level='DEBUG') as (handler, get_dataframe):
        driver.cartesian((0, 0, 1))
        df = get_dataframe()
        driver.cartesian((0, 0, 2))
        df2 = get_dataframe() # this is the cummulative log

# %%
df
# Out:
#                     asctime  \
# 0   2018-10-22 16:55:47,783
# 1   2018-10-22 16:55:47,784
# 2   2018-10-22 16:55:47,784
# 3   2018-10-22 16:55:47,784
# 4   2018-10-22 16:55:47,784
# 5   2018-10-22 16:55:47,784
# 6   2018-10-22 16:55:47,785
# 7   2018-10-22 16:55:47,785
# 8   2018-10-22 16:55:47,785
# 9   2018-10-22 16:55:47,785
# 10  2018-10-22 16:55:47,785
# 11  2018-10-22 16:55:47,786
# 12  2018-10-22 16:55:47,786
# 13  2018-10-22 16:55:47,786
# 14  2018-10-22 16:55:47,787
# 15  2018-10-22 16:55:47,787
# 16  2018-10-22 16:55:47,787
# 17  2018-10-22 16:55:47,787
# 18  2018-10-22 16:55:47,787
# 19  2018-10-22 16:55:47,788
# 20  2018-10-22 16:55:47,788
# 21  2018-10-22 16:55:47,788
# 22  2018-10-22 16:55:47,788
# 23  2018-10-22 16:55:47,788
# 24  2018-10-22 16:55:47,788
# 25  2018-10-22 16:55:47,788
# 26  2018-10-22 16:55:47,788
# 27  2018-10-22 16:55:47,789
# 28  2018-10-22 16:55:47,789
# 29  2018-10-22 16:55:47,789
# 30  2018-10-22 16:55:47,789
# 31  2018-10-22 16:55:47,789
# 32  2018-10-22 16:55:47,789
# 33  2018-10-22 16:55:47,789
# 34  2018-10-22 16:55:47,789
# 35  2018-10-22 16:55:47,789
# 36  2018-10-22 16:55:47,789
# 37  2018-10-22 16:55:47,790
# 38  2018-10-22 16:55:47,790
# 39  2018-10-22 16:55:47,790
# 40  2018-10-22 16:55:47,790
# 41  2018-10-22 16:55:47,790
# 42  2018-10-22 16:55:47,790
# 43  2018-10-22 16:55:47,790
# 44  2018-10-22 16:55:47,790
#
#                                                  name levelname  module  \
# 0   qcodes.instrument_drivers.american_magnetics.A...     DEBUG  AMI430
# 1                     qcodes.instrument.base.com.visa     DEBUG    visa
# 2                     qcodes.instrument.base.com.visa     DEBUG    visa
# 3                     qcodes.instrument.base.com.visa     DEBUG    visa
# 4                     qcodes.instrument.base.com.visa     DEBUG    visa
# 5                     qcodes.instrument.base.com.visa     DEBUG    visa
# 6                     qcodes.instrument.base.com.visa     DEBUG    visa
# 7   qcodes.instrument_drivers.american_magnetics.A...     DEBUG  AMI430
# 8                     qcodes.instrument.base.com.visa     DEBUG    visa
# 9                     qcodes.instrument.base.com.visa     DEBUG    visa
# 10                    qcodes.instrument.base.com.visa     DEBUG    visa
# 11                    qcodes.instrument.base.com.visa     DEBUG    visa
# 12                    qcodes.instrument.base.com.visa     DEBUG    visa
# 13                    qcodes.instrument.base.com.visa     DEBUG    visa
# 14                    qcodes.instrument.base.com.visa     DEBUG    visa
# 15                    qcodes.instrument.base.com.visa     DEBUG    visa
# 16                    qcodes.instrument.base.com.visa     DEBUG    visa
# 17                    qcodes.instrument.base.com.visa     DEBUG    visa
# 18                    qcodes.instrument.base.com.visa     DEBUG    visa
# 19                    qcodes.instrument.base.com.visa     DEBUG    visa
# 20                    qcodes.instrument.base.com.visa     DEBUG    visa
# 21                    qcodes.instrument.base.com.visa     DEBUG    visa
# 22                    qcodes.instrument.base.com.visa     DEBUG    visa
# 23                    qcodes.instrument.base.com.visa     DEBUG    visa
# 24                    qcodes.instrument.base.com.visa     DEBUG    visa
# 25                    qcodes.instrument.base.com.visa     DEBUG    visa
# 26                    qcodes.instrument.base.com.visa     DEBUG    visa
# 27                    qcodes.instrument.base.com.visa     DEBUG    visa
# 28                    qcodes.instrument.base.com.visa     DEBUG    visa
# 29                    qcodes.instrument.base.com.visa     DEBUG    visa
# 30                    qcodes.instrument.base.com.visa     DEBUG    visa
# 31                    qcodes.instrument.base.com.visa     DEBUG    visa
# 32                    qcodes.instrument.base.com.visa     DEBUG    visa
# 33                    qcodes.instrument.base.com.visa     DEBUG    visa
# 34                    qcodes.instrument.base.com.visa     DEBUG    visa
# 35                    qcodes.instrument.base.com.visa     DEBUG    visa
# 36                    qcodes.instrument.base.com.visa     DEBUG    visa
# 37                    qcodes.instrument.base.com.visa     DEBUG    visa
# 38                    qcodes.instrument.base.com.visa     DEBUG    visa
# 39  qcodes.instrument_drivers.american_magnetics.A...     DEBUG  AMI430
# 40                    qcodes.instrument.base.com.visa     DEBUG    visa
# 41                    qcodes.instrument.base.com.visa     DEBUG    visa
# 42                    qcodes.instrument.base.com.visa     DEBUG    visa
# 43                    qcodes.instrument.base.com.visa     DEBUG    visa
# 44  qcodes.instrument_drivers.american_magnetics.A...     DEBUG  AMI430
#
#                      funcName lineno  \
# 0   _adjust_child_instruments    688
# 1                     ask_raw    228
# 2                     ask_raw    230
# 3                     ask_raw    228
# 4                     ask_raw    230
# 5                     ask_raw    228
# 6                     ask_raw    230
# 7   _adjust_child_instruments    704
# 8                     ask_raw    228
# 9                     ask_raw    230
# 10                    ask_raw    228
# 11                    ask_raw    230
# 12                    ask_raw    228
# 13                    ask_raw    230
# 14                    ask_raw    228
# 15                    ask_raw    230
# 16                    ask_raw    228
# 17                    ask_raw    230
# 18                    ask_raw    228
# 19                    ask_raw    230
# 20                    ask_raw    228
# 21                    ask_raw    230
# 22                    ask_raw    228
# 23                    ask_raw    230
# 24                    ask_raw    228
# 25                    ask_raw    230
# 26                    ask_raw    228
# 27                    ask_raw    230
# 28                    ask_raw    228
# 29                    ask_raw    230
# 30                  write_raw    213
# 31                  write_raw    213
# 32                    ask_raw    228
# 33                    ask_raw    230
# 34                    ask_raw    228
# 35                    ask_raw    230
# 36                    ask_raw    228
# 37                    ask_raw    230
# 38                  write_raw    213
# 39                  set_field    333
# 40                    ask_raw    228
# 41                    ask_raw    230
# 42                    ask_raw    228
# 43                    ask_raw    230
# 44                  set_field    338
#
#                                         message
# 0            Checking whether fields can be set
# 1             [x(AMI430_VISA)] Querying: STATE?
# 2                  [x(AMI430_VISA)] Response: 2
# 3             [y(AMI430_VISA)] Querying: STATE?
# 4                  [y(AMI430_VISA)] Response: 2
# 5             [z(AMI430_VISA)] Querying: STATE?
# 6                  [z(AMI430_VISA)] Response: 2
# 7                   Field values OK, proceeding
# 8         [x(AMI430_VISA)] Querying: FIELD:MAG?
# 9                  [x(AMI430_VISA)] Response: 0
# 10        [y(AMI430_VISA)] Querying: FIELD:MAG?
# 11                 [y(AMI430_VISA)] Response: 0
# 12        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 13                 [z(AMI430_VISA)] Response: 0
# 14        [x(AMI430_VISA)] Querying: FIELD:MAG?
# 15                 [x(AMI430_VISA)] Response: 0
# 16        [y(AMI430_VISA)] Querying: FIELD:MAG?
# 17                 [y(AMI430_VISA)] Response: 0
# 18        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 19                 [z(AMI430_VISA)] Response: 0
# 20             [z(AMI430_VISA)] Querying: COIL?
# 21                 [z(AMI430_VISA)] Response: 1
# 22       [z(AMI430_VISA)] Querying: CURR:LIMIT?
# 23                [z(AMI430_VISA)] Response: 80
# 24               [z(AMI430_VISA)] Querying: QU?
# 25                 [z(AMI430_VISA)] Response: 0
# 26             [z(AMI430_VISA)] Querying: PERS?
# 27                 [z(AMI430_VISA)] Response: 0
# 28            [z(AMI430_VISA)] Querying: STATE?
# 29                 [z(AMI430_VISA)] Response: 2
# 30              [z(AMI430_VISA)] Writing: PAUSE
# 31  [z(AMI430_VISA)] Writing: CONF:FIELD:TARG 1
# 32          [z(AMI430_VISA)] Querying: PS:INST?
# 33             [z(AMI430_VISA)] Response: ERROR
# 34          [z(AMI430_VISA)] Querying: PS:INST?
# 35             [z(AMI430_VISA)] Response: ERROR
# 36               [z(AMI430_VISA)] Querying: PS?
# 37                 [z(AMI430_VISA)] Response: 0
# 38               [z(AMI430_VISA)] Writing: RAMP
# 39             Starting blocking ramp of z to 1
# 40            [z(AMI430_VISA)] Querying: STATE?
# 41                 [z(AMI430_VISA)] Response: 2
# 42            [z(AMI430_VISA)] Querying: STATE?
# 43                 [z(AMI430_VISA)] Response: 2
# 44                       Finished blocking ramp

# %%
df2
# Out:
#                     asctime  \
# 0   2018-10-22 16:55:47,783
# 1   2018-10-22 16:55:47,784
# 2   2018-10-22 16:55:47,784
# 3   2018-10-22 16:55:47,784
# 4   2018-10-22 16:55:47,784
# 5   2018-10-22 16:55:47,784
# 6   2018-10-22 16:55:47,785
# 7   2018-10-22 16:55:47,785
# 8   2018-10-22 16:55:47,785
# 9   2018-10-22 16:55:47,785
# 10  2018-10-22 16:55:47,785
# 11  2018-10-22 16:55:47,786
# 12  2018-10-22 16:55:47,786
# 13  2018-10-22 16:55:47,786
# 14  2018-10-22 16:55:47,787
# 15  2018-10-22 16:55:47,787
# 16  2018-10-22 16:55:47,787
# 17  2018-10-22 16:55:47,787
# 18  2018-10-22 16:55:47,787
# 19  2018-10-22 16:55:47,788
# 20  2018-10-22 16:55:47,788
# 21  2018-10-22 16:55:47,788
# 22  2018-10-22 16:55:47,788
# 23  2018-10-22 16:55:47,788
# 24  2018-10-22 16:55:47,788
# 25  2018-10-22 16:55:47,788
# 26  2018-10-22 16:55:47,788
# 27  2018-10-22 16:55:47,789
# 28  2018-10-22 16:55:47,789
# 29  2018-10-22 16:55:47,789
# ..                      ...
# 60  2018-10-22 16:55:47,802
# 61  2018-10-22 16:55:47,802
# 62  2018-10-22 16:55:47,803
# 63  2018-10-22 16:55:47,803
# 64  2018-10-22 16:55:47,803
# 65  2018-10-22 16:55:47,803
# 66  2018-10-22 16:55:47,803
# 67  2018-10-22 16:55:47,804
# 68  2018-10-22 16:55:47,804
# 69  2018-10-22 16:55:47,804
# 70  2018-10-22 16:55:47,804
# 71  2018-10-22 16:55:47,804
# 72  2018-10-22 16:55:47,805
# 73  2018-10-22 16:55:47,805
# 74  2018-10-22 16:55:47,805
# 75  2018-10-22 16:55:47,805
# 76  2018-10-22 16:55:47,805
# 77  2018-10-22 16:55:47,806
# 78  2018-10-22 16:55:47,806
# 79  2018-10-22 16:55:47,806
# 80  2018-10-22 16:55:47,806
# 81  2018-10-22 16:55:47,806
# 82  2018-10-22 16:55:47,807
# 83  2018-10-22 16:55:47,807
# 84  2018-10-22 16:55:47,807
# 85  2018-10-22 16:55:47,807
# 86  2018-10-22 16:55:47,807
# 87  2018-10-22 16:55:47,807
# 88  2018-10-22 16:55:47,808
# 89  2018-10-22 16:55:47,808
#
#                                                  name levelname  module  \
# 0   qcodes.instrument_drivers.american_magnetics.A...     DEBUG  AMI430
# 1                     qcodes.instrument.base.com.visa     DEBUG    visa
# 2                     qcodes.instrument.base.com.visa     DEBUG    visa
# 3                     qcodes.instrument.base.com.visa     DEBUG    visa
# 4                     qcodes.instrument.base.com.visa     DEBUG    visa
# 5                     qcodes.instrument.base.com.visa     DEBUG    visa
# 6                     qcodes.instrument.base.com.visa     DEBUG    visa
# 7   qcodes.instrument_drivers.american_magnetics.A...     DEBUG  AMI430
# 8                     qcodes.instrument.base.com.visa     DEBUG    visa
# 9                     qcodes.instrument.base.com.visa     DEBUG    visa
# 10                    qcodes.instrument.base.com.visa     DEBUG    visa
# 11                    qcodes.instrument.base.com.visa     DEBUG    visa
# 12                    qcodes.instrument.base.com.visa     DEBUG    visa
# 13                    qcodes.instrument.base.com.visa     DEBUG    visa
# 14                    qcodes.instrument.base.com.visa     DEBUG    visa
# 15                    qcodes.instrument.base.com.visa     DEBUG    visa
# 16                    qcodes.instrument.base.com.visa     DEBUG    visa
# 17                    qcodes.instrument.base.com.visa     DEBUG    visa
# 18                    qcodes.instrument.base.com.visa     DEBUG    visa
# 19                    qcodes.instrument.base.com.visa     DEBUG    visa
# 20                    qcodes.instrument.base.com.visa     DEBUG    visa
# 21                    qcodes.instrument.base.com.visa     DEBUG    visa
# 22                    qcodes.instrument.base.com.visa     DEBUG    visa
# 23                    qcodes.instrument.base.com.visa     DEBUG    visa
# 24                    qcodes.instrument.base.com.visa     DEBUG    visa
# 25                    qcodes.instrument.base.com.visa     DEBUG    visa
# 26                    qcodes.instrument.base.com.visa     DEBUG    visa
# 27                    qcodes.instrument.base.com.visa     DEBUG    visa
# 28                    qcodes.instrument.base.com.visa     DEBUG    visa
# 29                    qcodes.instrument.base.com.visa     DEBUG    visa
# ..                                                ...       ...     ...
# 60                    qcodes.instrument.base.com.visa     DEBUG    visa
# 61                    qcodes.instrument.base.com.visa     DEBUG    visa
# 62                    qcodes.instrument.base.com.visa     DEBUG    visa
# 63                    qcodes.instrument.base.com.visa     DEBUG    visa
# 64                    qcodes.instrument.base.com.visa     DEBUG    visa
# 65                    qcodes.instrument.base.com.visa     DEBUG    visa
# 66                    qcodes.instrument.base.com.visa     DEBUG    visa
# 67                    qcodes.instrument.base.com.visa     DEBUG    visa
# 68                    qcodes.instrument.base.com.visa     DEBUG    visa
# 69                    qcodes.instrument.base.com.visa     DEBUG    visa
# 70                    qcodes.instrument.base.com.visa     DEBUG    visa
# 71                    qcodes.instrument.base.com.visa     DEBUG    visa
# 72                    qcodes.instrument.base.com.visa     DEBUG    visa
# 73                    qcodes.instrument.base.com.visa     DEBUG    visa
# 74                    qcodes.instrument.base.com.visa     DEBUG    visa
# 75                    qcodes.instrument.base.com.visa     DEBUG    visa
# 76                    qcodes.instrument.base.com.visa     DEBUG    visa
# 77                    qcodes.instrument.base.com.visa     DEBUG    visa
# 78                    qcodes.instrument.base.com.visa     DEBUG    visa
# 79                    qcodes.instrument.base.com.visa     DEBUG    visa
# 80                    qcodes.instrument.base.com.visa     DEBUG    visa
# 81                    qcodes.instrument.base.com.visa     DEBUG    visa
# 82                    qcodes.instrument.base.com.visa     DEBUG    visa
# 83                    qcodes.instrument.base.com.visa     DEBUG    visa
# 84  qcodes.instrument_drivers.american_magnetics.A...     DEBUG  AMI430
# 85                    qcodes.instrument.base.com.visa     DEBUG    visa
# 86                    qcodes.instrument.base.com.visa     DEBUG    visa
# 87                    qcodes.instrument.base.com.visa     DEBUG    visa
# 88                    qcodes.instrument.base.com.visa     DEBUG    visa
# 89  qcodes.instrument_drivers.american_magnetics.A...     DEBUG  AMI430
#
#                      funcName lineno  \
# 0   _adjust_child_instruments    688
# 1                     ask_raw    228
# 2                     ask_raw    230
# 3                     ask_raw    228
# 4                     ask_raw    230
# 5                     ask_raw    228
# 6                     ask_raw    230
# 7   _adjust_child_instruments    704
# 8                     ask_raw    228
# 9                     ask_raw    230
# 10                    ask_raw    228
# 11                    ask_raw    230
# 12                    ask_raw    228
# 13                    ask_raw    230
# 14                    ask_raw    228
# 15                    ask_raw    230
# 16                    ask_raw    228
# 17                    ask_raw    230
# 18                    ask_raw    228
# 19                    ask_raw    230
# 20                    ask_raw    228
# 21                    ask_raw    230
# 22                    ask_raw    228
# 23                    ask_raw    230
# 24                    ask_raw    228
# 25                    ask_raw    230
# 26                    ask_raw    228
# 27                    ask_raw    230
# 28                    ask_raw    228
# 29                    ask_raw    230
# ..                        ...    ...
# 60                    ask_raw    230
# 61                    ask_raw    228
# 62                    ask_raw    230
# 63                    ask_raw    228
# 64                    ask_raw    230
# 65                    ask_raw    228
# 66                    ask_raw    230
# 67                    ask_raw    228
# 68                    ask_raw    230
# 69                    ask_raw    228
# 70                    ask_raw    230
# 71                    ask_raw    228
# 72                    ask_raw    230
# 73                    ask_raw    228
# 74                    ask_raw    230
# 75                  write_raw    213
# 76                  write_raw    213
# 77                    ask_raw    228
# 78                    ask_raw    230
# 79                    ask_raw    228
# 80                    ask_raw    230
# 81                    ask_raw    228
# 82                    ask_raw    230
# 83                  write_raw    213
# 84                  set_field    333
# 85                    ask_raw    228
# 86                    ask_raw    230
# 87                    ask_raw    228
# 88                    ask_raw    230
# 89                  set_field    338
#
#                                         message
# 0            Checking whether fields can be set
# 1             [x(AMI430_VISA)] Querying: STATE?
# 2                  [x(AMI430_VISA)] Response: 2
# 3             [y(AMI430_VISA)] Querying: STATE?
# 4                  [y(AMI430_VISA)] Response: 2
# 5             [z(AMI430_VISA)] Querying: STATE?
# 6                  [z(AMI430_VISA)] Response: 2
# 7                   Field values OK, proceeding
# 8         [x(AMI430_VISA)] Querying: FIELD:MAG?
# 9                  [x(AMI430_VISA)] Response: 0
# 10        [y(AMI430_VISA)] Querying: FIELD:MAG?
# 11                 [y(AMI430_VISA)] Response: 0
# 12        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 13                 [z(AMI430_VISA)] Response: 0
# 14        [x(AMI430_VISA)] Querying: FIELD:MAG?
# 15                 [x(AMI430_VISA)] Response: 0
# 16        [y(AMI430_VISA)] Querying: FIELD:MAG?
# 17                 [y(AMI430_VISA)] Response: 0
# 18        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 19                 [z(AMI430_VISA)] Response: 0
# 20             [z(AMI430_VISA)] Querying: COIL?
# 21                 [z(AMI430_VISA)] Response: 1
# 22       [z(AMI430_VISA)] Querying: CURR:LIMIT?
# 23                [z(AMI430_VISA)] Response: 80
# 24               [z(AMI430_VISA)] Querying: QU?
# 25                 [z(AMI430_VISA)] Response: 0
# 26             [z(AMI430_VISA)] Querying: PERS?
# 27                 [z(AMI430_VISA)] Response: 0
# 28            [z(AMI430_VISA)] Querying: STATE?
# 29                 [z(AMI430_VISA)] Response: 2
# ..                                          ...
# 60                 [x(AMI430_VISA)] Response: 0
# 61        [y(AMI430_VISA)] Querying: FIELD:MAG?
# 62                 [y(AMI430_VISA)] Response: 0
# 63        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 64                 [z(AMI430_VISA)] Response: 1
# 65             [z(AMI430_VISA)] Querying: COIL?
# 66                 [z(AMI430_VISA)] Response: 1
# 67       [z(AMI430_VISA)] Querying: CURR:LIMIT?
# 68                [z(AMI430_VISA)] Response: 80
# 69               [z(AMI430_VISA)] Querying: QU?
# 70                 [z(AMI430_VISA)] Response: 0
# 71             [z(AMI430_VISA)] Querying: PERS?
# 72                 [z(AMI430_VISA)] Response: 0
# 73            [z(AMI430_VISA)] Querying: STATE?
# 74                 [z(AMI430_VISA)] Response: 2
# 75              [z(AMI430_VISA)] Writing: PAUSE
# 76  [z(AMI430_VISA)] Writing: CONF:FIELD:TARG 2
# 77          [z(AMI430_VISA)] Querying: PS:INST?
# 78             [z(AMI430_VISA)] Response: ERROR
# 79          [z(AMI430_VISA)] Querying: PS:INST?
# 80             [z(AMI430_VISA)] Response: ERROR
# 81               [z(AMI430_VISA)] Querying: PS?
# 82                 [z(AMI430_VISA)] Response: 0
# 83               [z(AMI430_VISA)] Writing: RAMP
# 84             Starting blocking ramp of z to 2
# 85            [z(AMI430_VISA)] Querying: STATE?
# 86                 [z(AMI430_VISA)] Response: 2
# 87            [z(AMI430_VISA)] Querying: STATE?
# 88                 [z(AMI430_VISA)] Response: 2
# 89                       Finished blocking ramp
#
# [90 rows x 7 columns]

# %% [markdown]
# You can of course combine the context managers like this:

# %%
with logger.console_level(logging.WARN):
    driver.cartesian((0, 0, 0))
    with logger.capture_dataframe(level='DEBUG') as (handler, get_dataframe):
        with logger.filter_instrument(mag_x, handler=handler):
            driver.cartesian((0, 0, 1))
            df = get_dataframe()
df
# Out:
#                    asctime                             name levelname module  \
# 0  2018-10-22 16:55:52,173  qcodes.instrument.base.com.visa     DEBUG   visa
# 1  2018-10-22 16:55:52,173  qcodes.instrument.base.com.visa     DEBUG   visa
# 2  2018-10-22 16:55:52,174  qcodes.instrument.base.com.visa     DEBUG   visa
# 3  2018-10-22 16:55:52,174  qcodes.instrument.base.com.visa     DEBUG   visa
# 4  2018-10-22 16:55:52,175  qcodes.instrument.base.com.visa     DEBUG   visa
# 5  2018-10-22 16:55:52,175  qcodes.instrument.base.com.visa     DEBUG   visa
#
#   funcName lineno                                message
# 0  ask_raw    228      [x(AMI430_VISA)] Querying: STATE?
# 1  ask_raw    230           [x(AMI430_VISA)] Response: 2
# 2  ask_raw    228  [x(AMI430_VISA)] Querying: FIELD:MAG?
# 3  ask_raw    230           [x(AMI430_VISA)] Response: 0
# 4  ask_raw    228  [x(AMI430_VISA)] Querying: FIELD:MAG?
# 5  ask_raw    230           [x(AMI430_VISA)] Response: 0

# %% [markdown]
# For an analysis of the timestamps please also refer to the log analysis example notebook ([online](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/logging/logfile_parsing.ipynb), [offline](logfile_parsing.ipynb)).
