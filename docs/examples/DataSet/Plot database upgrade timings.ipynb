# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

# %%
# Results from original version; git hash 4f3232c9d497ba2c270f1bc07d27fb0d51f7005b 

no_of_runs = [10, 50, 250, 1250, 6250, 10000]
sql_query_times = [0.008, 0.035, 0.220, 1.806, 43.986, 135.483]
sql_update_times = [0.001, 0.003, 0.011, 0.044, 0.234, 0.329]
yaml_times = [0.087, 0.403, 1.821, 7.183, 34.319, 56.895]

# %%
fig, ax = plt.subplots()
ax.plot(no_of_runs, sql_query_times, 'o--', label='SQL queries')
ax.plot(no_of_runs, yaml_times, 'o--', label='Object serialization')
ax.plot(no_of_runs, sql_update_times, 'o--', label='SQL Updates')
#ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_xlabel('No of runs')
ax.set_ylabel('Time consumption (s)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Results from first refactor/speed up; git hash ceb55b51c7cf6457213ffedf855648dd36f29331 

no_of_runs = [10, 50, 250, 1250, 6250, 10000]
sql_query_times_new = [0.007, 0.031, 0.159, 1.323, 16.422, 45.328]

# %%
fig, ax = plt.subplots()
ax.plot(no_of_runs, sql_query_times, 'o--', label='SQL queries (old)')
ax.plot(no_of_runs, sql_query_times_new, 'o--', label='SQL queries (new)')

#ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_xlabel('No of runs')
ax.set_ylabel('Time consumption (s)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# results from second round of refactor/speed up; git hash 9995b197fe8514e8aac5a3806567d9331a74d7a4 
no_of_runs = [10, 50, 250, 1250, 6250, 10000]
sql_query_times = [0.005, 0.014, 0.067, 0.369, 1.824,  2.935]
sql_update_times = [0.001, 0.002, 0.010, 0.055,  0.313, 0.473]
yaml_times = [0.082, 0.361, 1.596, 8.641, 40.391, 58.107]

# %%
fig, ax = plt.subplots()
ax.plot(no_of_runs, sql_query_times, 'o--', label='SQL queries')
ax.plot(no_of_runs, yaml_times, 'o--', label='Object serialization')
ax.plot(no_of_runs, sql_update_times, 'o--', label='SQL Updates')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('No of runs')
ax.set_ylabel('Time consumption (s)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# results from using JSON
no_of_runs = [10, 50, 250, 1250, 6250, 10000]
sql_query_times = [0.013, 0.030, 0.142, 0.359, 1.673, 2.476]
sql_update_times = [0.001, 0.003, 0.006, 0.034, 0.191, 0.256]
yaml_times = [0.001,  0.004, 0.013, 0.070, 0.310, 0.421 ]

# %%
fig, ax = plt.subplots()
ax.plot(no_of_runs, sql_query_times, 'o--', label='SQL queries')
ax.plot(no_of_runs, yaml_times, 'o--', label='Object serialization')
ax.plot(no_of_runs, sql_update_times, 'o--', label='SQL Updates')
#ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_xlabel('No of runs')
ax.set_ylabel('Time consumption (s)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
