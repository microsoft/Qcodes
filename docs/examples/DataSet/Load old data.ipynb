# %% [markdown]
# # Load old Data

# %%
import qcodes as qc
from qcodes.dataset.legacy_import import import_dat_file

from qcodes.dataset.measurements import Measurement
from qcodes.dataset.plotting import plot_by_id
import numpy as np
# Out:
# /Users/jhn/.pyenv/versions/3.6.4/envs/qcodes-3.6.4/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
location = '../data/2018-01-17/#002_2D_test_15-43-14'
location1d = '../data/2018-01-18/#001_testsweep_17-00-05'

# %%
run_ids = import_dat_file(location)
fig = plot_by_id(run_ids[0])
# Out:
# Starting experimental run with id: 27

# %%
run_ids = import_dat_file(location1d)
fig = plot_by_id(run_ids[0])
# Out:
# Starting experimental run with id: 28

# %%
location1d = '../data/2018-01-18/#001_testsweep_17-00-05'
loaded_data_1d = qc.load_data(location1d)
