# %%
from qcodes import load_by_run_spec
import time

# %%
a = load_by_run_spec(captured_run_id=58)

# %%
while True:
    time.sleep(0.5)
    a.cache_parameter_data()
    print(a.data)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# {'dmm_v1': {'dmm_v1': array([5.18929998, 4.79780975, 4.44457856, 4.34407302]), 'dac_ch1': array([0.        , 0.25252525, 0.50505051, 0.75757576])}}
# {'dmm_v1': {'dmm_v1': array([5.18929998, 4.79780975, 4.44457856, 4.34407302, 4.04256774,
#        4.03477279, 3.75598471, 3.55290078]), 'dac_ch1': array([0.        , 0.25252525, 0.50505051, 0.75757576, 1.01010101,
#        1.26262626, 1.51515152, 1.76767677])}}
# {'dmm_v1': {'dmm_v1': array([5.18929998, 4.79780975, 4.44457856, 4.34407302, 4.04256774,
#        4.03477279, 3.75598471, 3.55290078, 3.38329372, 3.17289219,
#        3.03182361, 2.9615758 , 2.67323431]), 'dac_ch1': array([0.        , 0.25252525, 0.50505051, 0.75757576, 1.01010101,
#        1.26262626, 1.51515152, 1.76767677, 2.02020202, 2.27272727,
#        2.52525253, 2.77777778, 3.03030303])}}
# ...
