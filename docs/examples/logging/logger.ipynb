# %% [markdown]
# # Logging
# (back to the overview [offline](../main.ipynb),[online](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/main.ipynb))
#
# [read on nbviewer](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/logging/logger.ipynb)

# %% [markdown]
# # TL;DR
#  * There is a QCoDeS logging module: `qcodes.utils.logger`
#  * Call `logger.start_all_logging` at the start of every script/session to make sure all log messages get stored to the `.qcodes/logs` folder in your home directory.
#  * For debugging purposes you can log messages of an individual instrument (and see the VISA dialog).
#  * You can obtain all logging messages in a `pandas.DataFrame` for further analysis.

# %% [markdown]
# # Contents
# - [Introduction](#Introduction)
# - [Set up logging in QCoDeS](#Set-up-logging-in-QCoDeS)
#   - [QCoDeS default handlers](#QCoDeS-default-handlers)
#   - [IPython command history](#IPython-command-history)
# - [Temporarily elevating the logging level](#Temporarily-elevating-the-logging-level)
# - [Filtering log messages by instrument](#Filtering-log-messages-by-instrument)
# - [Capturing Pandas.DataFrame](#Capturing-Pandas.DataFrame)

# %% [markdown]
# # Introduction
# Python offers an excellent logging framework that is widely used in QCoDeS. As a user you might be interested in reading the log messages that are generated by QCoDeS for debugging and also profiling purposes.
#
# All log records(=messages+meta data) are created using a python `logging.logger` object. In QCoDeS there is a logger for every module with the same name as the module itself, i.e. you can use `logging.getLogger('qcodes.instrument_drivers.Lakeshore.Model_372')` for getting the logger of the Lakeshore temperature controller. From the dots in the names of the loggers a hierarchy is define, at the top of which is the so called *root logger* that catches all messages.
# The log records created in a logger are processed by the *handlers* that have been attached to this specific *logger*.
# The handlers can for example be used to output the log messages into different locations, like the console or a log file.
#
# Every logger, handler and log record has an associated level. The default levels are: `CRITICAL` `ERROR`, `WARNING`, `INFO`, `DEBUG`. The levels determine how messages are passed: A logger passes only records that exceeds its minimal passing level to its handlers and the handlers in turn only output those messages that exceed their minimal passing level.
#
#
# For a more detailed description of Python logging refer to the [official manual](https://docs.python.org/3.6/library/logging.html#module-logging) (This is all well summed up [in this chart](https://docs.python.org/3.6/howto/logging.html#logging-flow))

# %% [markdown]
# # Set up logging in QCoDeS
# At the beginning of every experiment script file you should include the following lines:

# %%
from qcodes.logger import start_all_logging
start_all_logging()
# Out:
# Logging hadn't been started.
# Activating auto-logging. Current session state plus future input saved.
# Filename       : C:\Users\a-dovoge\.qcodes\logs\command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-bf954c836d37>", line 2, in <module>
#     start_all_logging()
#   File "c:\users\a-dovoge\qcodes\qcodes\logger\logger.py", line 195, in start_all_logging
#     start_logger()
#   File "c:\users\a-dovoge\qcodes\qcodes\logger\logger.py", line 164, in start_logger
#     log.info("QCoDes logger setup completed")
# Message: 'QCoDes logger setup completed'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-bf954c836d37>", line 2, in <module>
#     start_all_logging()
#   File "c:\users\a-dovoge\qcodes\qcodes\logger\logger.py", line 195, in start_all_logging
#     start_logger()
#   File "c:\users\a-dovoge\qcodes\qcodes\logger\logger.py", line 164, in start_logger
#     log.info("QCoDes logger setup completed")
# Message: 'QCoDes logger setup completed'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-bf954c836d37>", line 2, in <module>
#     start_all_logging()
#   File "c:\users\a-dovoge\qcodes\qcodes\logger\logger.py", line 196, in start_all_logging
#     start_command_history_logger()
#   File "c:\users\a-dovoge\qcodes\qcodes\logger\logger.py", line 188, in start_command_history_logger
#     log.info("Started logging IPython history")
# Message: 'Started logging IPython history'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-bf954c836d37>", line 2, in <module>
#     start_all_logging()
#   File "c:\users\a-dovoge\qcodes\qcodes\logger\logger.py", line 196, in start_all_logging
#     start_command_history_logger()
#   File "c:\users\a-dovoge\qcodes\qcodes\logger\logger.py", line 188, in start_command_history_logger
#     log.info("Started logging IPython history")
# Message: 'Started logging IPython history'
# Arguments: ()

# %% [markdown]
# The call to `start_all_logging` does two things:
# 1. Create handlers to output logging messages from the root logger to the console and to a log file.
# 2. Enable logging of the ipython commands into a separate log file.

# %% [markdown]
# ## QCoDeS default handlers
# The effect of the console handler can be seen in the two printed lines with a red background below the previous code cell. Every line corresponds to a log record. The fields of the records are separated by `¦` and have the following meaning:
#  0. time stamp
#  1. logger name, here the module name
#  2. record log level
#  3. name of the function that created the log message
#  4. line at which the message has been issued
#  5. actual log message
#
# The same format is used for the file handler. By default QCoDeS logs to the file `<user directory>/.qcodes/logs/qcodes.log`. To avoid endlessly long files, the files roll over at midnight and get the date appended to their name where `qcodes.log` without date always gives you the log messages of the same day.
#
# To configure the levels you want to log/handle, you need to edit the `qcodesrc.json` file in you home directory. The default values are:
# ```
#     "logger":{
#         "console_level": "WARNING",
#         "file_level": "INFO",
#         "logger_levels":{
#             "pyvisa": "INFO"
#         }
# ```
# While `console_level` and `file_level` describe the levels of the two default handlers described previously, `logger_levels` is a dictionary that can be used to limit the messages passed on by module level loggers. This means with these defaults, the pyvisa module will not log messages on a `DEBUG` level. Therefore setting the `console_level` to `DEBUG` will not show the pyvisa debug messages (you certainly don't want to see them as they log every single character that is passed to an instrument with an individual message). On the other hand setting the console level to warning will still suppress pyvisa info messages.

# %% [markdown]
# ## IPython command history
# The output above that follows these logging messages comes from IPython. It tells us that all issued IPython commands will be logged to a file. The file lives in the same log directory as the python logs and is called `command_history.log`. It will not roll over.
#
# To change the command history logging directory you will need to call `start_command_history_logger` with the new path as an argument.

# %% [markdown]
# # Temporarily elevating the logging level
# Sometimes you might wish to catch e.g. all debug messages for a few lines of code. You can do this simply by:

# %%
import logging
import qcodes.logger as logger
log = logging.getLogger('example_logger')

log.debug('This message will not be visible as the logging level is set to `DEBUG`')

with logger.console_level(logging.DEBUG):
    log.debug('This message is visible as the logging level is temporarily elevated to `DEBUG`')
    
log.debug('The level is back to what it used to be')
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-c7e8205cb86b>", line 8, in <module>
#     log.debug('This message is visible as the logging level is temporarily elevated to `DEBUG`')
# Message: 'This message is visible as the logging level is temporarily elevated to `DEBUG`'
# Arguments: ()

# %% [markdown]
# For other handlers than the console handler you can do the same thing using the `handler_level` context manager.

# %% [markdown]
# # Filtering log messages by instrument
# A very common use case for logging in qcodes is to analyze the communication with a VISA instrument. For this purpose the logger module provides a context manager to filter the logging messages by instrument.
#
# Generally one could of course simply attach a handler to the logger of `qcodes.instrument_drivers.Vendor.Type` but this would not show the messages that are generated by the visa communication in `qcodes.instrument.visa`. Additionally with the approach implemented here one can not only filter messages for a given type of instrument but also of a specific instance.
#
# To demonstrate this consider the following mock up of the AMI430 Magnet controller that consists of individual visa instruments for each axis, here with the names `x`, `y` and `z`:

# %%
from qcodes.instrument.ip_to_visa import AMI430_VISA
from qcodes.instrument_drivers.american_magnetics.AMI430 import AMI430_3D, AMI430Warning

import qcodes.instrument.sims as sims

visalib = sims.__file__.replace('__init__.py', 'AMI430.yaml@sim')

mag_x = AMI430_VISA('x', address='GPIB::1::INSTR', visalib=visalib,
                        terminator='\n', port=1)
mag_y = AMI430_VISA('y', address='GPIB::2::INSTR', visalib=visalib,
                        terminator='\n', port=1)
mag_z = AMI430_VISA('z', address='GPIB::3::INSTR', visalib=visalib,
                        terminator='\n', port=1)

import numpy as np
field_limit = [
    lambda x, y, z: x == 0 and y == 0 and z < 3,
    lambda x, y, z: np.linalg.norm([x, y, z]) < 2
]

driver = AMI430_3D("AMI430-3D", mag_x, mag_y, mag_z, field_limit)
# Out:
# 2018-10-19 14:49:24,792 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 115 ¦ x ¦ [x(AMI430_VISA)] Opening PyVISA Resource Manager with visalib: c:\users\a-dovoge\qcodes\qcodes\instrument\sims\AMI430.yaml@sim
# 2018-10-19 14:49:25,276 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 124 ¦ x ¦ [x(AMI430_VISA)] Opening PyVISA resource at address: GPIB::1::INSTR
# 2018-10-19 14:49:25,286 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 115 ¦ y ¦ [y(AMI430_VISA)] Opening PyVISA Resource Manager with visalib: c:\users\a-dovoge\qcodes\qcodes\instrument\sims\AMI430.yaml@sim
# 2018-10-19 14:49:25,287 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 124 ¦ y ¦ [y(AMI430_VISA)] Opening PyVISA resource at address: GPIB::2::INSTR
# 2018-10-19 14:49:25,304 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 115 ¦ z ¦ [z(AMI430_VISA)] Opening PyVISA Resource Manager with visalib: c:\users\a-dovoge\qcodes\qcodes\instrument\sims\AMI430.yaml@sim
# 2018-10-19 14:49:25,311 ¦ qcodes.instrument.base.com.visa ¦ INFO ¦ visa ¦ set_address ¦ 124 ¦ z ¦ [z(AMI430_VISA)] Opening PyVISA resource at address: GPIB::3::INSTR
# Connected to: QCoDeS AMI430_simulation (serial:1337, firmware:0.0.01) in 0.49s
# Connected to: QCoDeS AMI430_simulation (serial:1337, firmware:0.0.01) in 0.01s
# Connected to: QCoDeS AMI430_simulation (serial:1337, firmware:0.0.01) in 0.02s

# %% [markdown]
# In the above messages you can see the prefix `[<instrument_name>(<instrument_type>)]`. To analyze the visa communication one can use `filter_instrument`:

# %%
driver.cartesian((0, 0, 0))
with logger.console_level('DEBUG'):
    with logger.filter_instrument(mag_x):
        driver.cartesian((0, 0, 1))
# Out:
# 2018-10-19 14:49:25,385 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ x ¦ [x(AMI430_VISA)] Querying: STATE?
# 2018-10-19 14:49:25,387 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ x ¦ [x(AMI430_VISA)] Response: 2
# 2018-10-19 14:49:25,398 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ x ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-19 14:49:25,400 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ x ¦ [x(AMI430_VISA)] Response: 0
# 2018-10-19 14:49:25,403 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ x ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-19 14:49:25,406 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ x ¦ [x(AMI430_VISA)] Response: 0

# %% [markdown]
# The output on the console shows as expected only messages from the `x` instrument. For multiple instruments pass a sequence of instruments to `filter_instrument`:

# %%
driver.cartesian((0, 0, 0))
with logger.console_level('DEBUG'):
    with logger.filter_instrument((mag_x, mag_y)):
        driver.cartesian((0, 0, 1))
# Out:
# 2018-10-19 14:49:25,448 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ x ¦ [x(AMI430_VISA)] Querying: STATE?
# 2018-10-19 14:49:25,450 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ x ¦ [x(AMI430_VISA)] Response: 2
# 2018-10-19 14:49:25,452 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ y ¦ [y(AMI430_VISA)] Querying: STATE?
# 2018-10-19 14:49:25,453 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ y ¦ [y(AMI430_VISA)] Response: 2
# 2018-10-19 14:49:25,461 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ x ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-19 14:49:25,464 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ x ¦ [x(AMI430_VISA)] Response: 0
# 2018-10-19 14:49:25,467 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ y ¦ [y(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-19 14:49:25,469 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ y ¦ [y(AMI430_VISA)] Response: 0
# 2018-10-19 14:49:25,471 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ x ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-19 14:49:25,477 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ x ¦ [x(AMI430_VISA)] Response: 0
# 2018-10-19 14:49:25,479 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 228 ¦ y ¦ [y(AMI430_VISA)] Querying: FIELD:MAG?
# 2018-10-19 14:49:25,480 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 230 ¦ y ¦ [y(AMI430_VISA)] Response: 0

# %% [markdown]
# # Capturing Pandas.DataFrame
# To process the logs, especially with the timestamps the [pandas module](https://pandas.pydata.org/) is highly suited. With `logger.log_to_dataframe` or `logger.logfile_to_dataframe` you can convert a log(file) to a pandas `DataFrame`. See this ([online](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/logging/logfile_parsing.ipynb), [offline](logfile_parsing_ipynb)) notebook for an example.
#
# You can also use a context manager to capture the logs directly into a `DataFrame`

# %%
with logger.console_level(logging.WARN):
    driver.cartesian((0, 0, 0))
    with logger.capture_dataframe(level='DEBUG') as (handler, get_dataframe):
        driver.cartesian((0, 0, 1))
        df = get_dataframe()
        driver.cartesian((0, 0, 2))
        df2 = get_dataframe() # this is the cummulative log
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-f22acd052feb>", line 4, in <module>
#     driver.cartesian((0, 0, 1))
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 288, in __call__
#     self.set(*args, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 466, in set_wrapper
#     set_function(raw_value, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\utils\command.py", line 177, in __call__
#     return self.exec_function(*args)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 790, in _set_setpoints
#     set_point.get_components("x", "y", "z")
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 688, in _adjust_child_instruments
#     log.debug("Checking whether fields can be set")
# Message: 'Checking whether fields can be set'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-f22acd052feb>", line 4, in <module>
#     driver.cartesian((0, 0, 1))
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 288, in __call__
#     self.set(*args, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 466, in set_wrapper
#     set_function(raw_value, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\utils\command.py", line 177, in __call__
#     return self.exec_function(*args)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 790, in _set_setpoints
#     set_point.get_components("x", "y", "z")
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 704, in _adjust_child_instruments
#     log.debug("Field values OK, proceeding")
# Message: 'Field values OK, proceeding'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-f22acd052feb>", line 4, in <module>
#     driver.cartesian((0, 0, 1))
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 288, in __call__
#     self.set(*args, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 466, in set_wrapper
#     set_function(raw_value, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\utils\command.py", line 177, in __call__
#     return self.exec_function(*args)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 790, in _set_setpoints
#     set_point.get_components("x", "y", "z")
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 724, in _adjust_child_instruments
#     block=self.block_during_ramp.get())
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 333, in set_field
#     log.debug(f'Starting blocking ramp of {self.name} to {value}')
# Message: 'Starting blocking ramp of z to 1'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-f22acd052feb>", line 4, in <module>
#     driver.cartesian((0, 0, 1))
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 288, in __call__
#     self.set(*args, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 466, in set_wrapper
#     set_function(raw_value, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\utils\command.py", line 177, in __call__
#     return self.exec_function(*args)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 790, in _set_setpoints
#     set_point.get_components("x", "y", "z")
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 724, in _adjust_child_instruments
#     block=self.block_during_ramp.get())
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 338, in set_field
#     log.debug(f'Finished blocking ramp')
# Message: 'Finished blocking ramp'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-f22acd052feb>", line 6, in <module>
#     driver.cartesian((0, 0, 2))
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 288, in __call__
#     self.set(*args, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 466, in set_wrapper
#     set_function(raw_value, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\utils\command.py", line 177, in __call__
#     return self.exec_function(*args)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 790, in _set_setpoints
#     set_point.get_components("x", "y", "z")
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 688, in _adjust_child_instruments
#     log.debug("Checking whether fields can be set")
# Message: 'Checking whether fields can be set'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-f22acd052feb>", line 6, in <module>
#     driver.cartesian((0, 0, 2))
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 288, in __call__
#     self.set(*args, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 466, in set_wrapper
#     set_function(raw_value, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\utils\command.py", line 177, in __call__
#     return self.exec_function(*args)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 790, in _set_setpoints
#     set_point.get_components("x", "y", "z")
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 704, in _adjust_child_instruments
#     log.debug("Field values OK, proceeding")
# Message: 'Field values OK, proceeding'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-f22acd052feb>", line 6, in <module>
#     driver.cartesian((0, 0, 2))
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 288, in __call__
#     self.set(*args, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 466, in set_wrapper
#     set_function(raw_value, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\utils\command.py", line 177, in __call__
#     return self.exec_function(*args)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 790, in _set_setpoints
#     set_point.get_components("x", "y", "z")
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 724, in _adjust_child_instruments
#     block=self.block_during_ramp.get())
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 333, in set_field
#     log.debug(f'Starting blocking ramp of {self.name} to {value}')
# Message: 'Starting blocking ramp of z to 2'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 838, in format
#     return fmt.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 578, in format
#     s = self.formatMessage(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 547, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\a-dovoge\anaconda3\lib\logging\__init__.py", line 391, in format
#     return self._fmt % record.__dict__
# KeyError: 'instrument_name'
# Call stack:
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\a-dovoge\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\a-dovoge\anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\a-dovoge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-f22acd052feb>", line 6, in <module>
#     driver.cartesian((0, 0, 2))
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 288, in __call__
#     self.set(*args, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument\parameter.py", line 466, in set_wrapper
#     set_function(raw_value, **kwargs)
#   File "c:\users\a-dovoge\qcodes\qcodes\utils\command.py", line 177, in __call__
#     return self.exec_function(*args)
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 790, in _set_setpoints
#     set_point.get_components("x", "y", "z")
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 724, in _adjust_child_instruments
#     block=self.block_during_ramp.get())
#   File "c:\users\a-dovoge\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py", line 338, in set_field
#     log.debug(f'Finished blocking ramp')
# Message: 'Finished blocking ramp'
# Arguments: ()

# %%
df
# Out:
#                     asctime                             name levelname module  \
# 0   2018-10-19 14:49:25,616  qcodes.instrument.base.com.visa     DEBUG   visa
# 1   2018-10-19 14:49:25,617  qcodes.instrument.base.com.visa     DEBUG   visa
# 2   2018-10-19 14:49:25,617  qcodes.instrument.base.com.visa     DEBUG   visa
# 3   2018-10-19 14:49:25,617  qcodes.instrument.base.com.visa     DEBUG   visa
# 4   2018-10-19 14:49:25,617  qcodes.instrument.base.com.visa     DEBUG   visa
# 5   2018-10-19 14:49:25,618  qcodes.instrument.base.com.visa     DEBUG   visa
# 6   2018-10-19 14:49:25,633  qcodes.instrument.base.com.visa     DEBUG   visa
# 7   2018-10-19 14:49:25,633  qcodes.instrument.base.com.visa     DEBUG   visa
# 8   2018-10-19 14:49:25,634  qcodes.instrument.base.com.visa     DEBUG   visa
# 9   2018-10-19 14:49:25,634  qcodes.instrument.base.com.visa     DEBUG   visa
# 10  2018-10-19 14:49:25,634  qcodes.instrument.base.com.visa     DEBUG   visa
# 11  2018-10-19 14:49:25,635  qcodes.instrument.base.com.visa     DEBUG   visa
# 12  2018-10-19 14:49:25,635  qcodes.instrument.base.com.visa     DEBUG   visa
# 13  2018-10-19 14:49:25,635  qcodes.instrument.base.com.visa     DEBUG   visa
# 14  2018-10-19 14:49:25,635  qcodes.instrument.base.com.visa     DEBUG   visa
# 15  2018-10-19 14:49:25,636  qcodes.instrument.base.com.visa     DEBUG   visa
# 16  2018-10-19 14:49:25,636  qcodes.instrument.base.com.visa     DEBUG   visa
# 17  2018-10-19 14:49:25,637  qcodes.instrument.base.com.visa     DEBUG   visa
# 18  2018-10-19 14:49:25,637  qcodes.instrument.base.com.visa     DEBUG   visa
# 19  2018-10-19 14:49:25,638  qcodes.instrument.base.com.visa     DEBUG   visa
# 20  2018-10-19 14:49:25,638  qcodes.instrument.base.com.visa     DEBUG   visa
# 21  2018-10-19 14:49:25,638  qcodes.instrument.base.com.visa     DEBUG   visa
# 22  2018-10-19 14:49:25,638  qcodes.instrument.base.com.visa     DEBUG   visa
# 23  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 24  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 25  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 26  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 27  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 28  2018-10-19 14:49:25,640  qcodes.instrument.base.com.visa     DEBUG   visa
# 29  2018-10-19 14:49:25,640  qcodes.instrument.base.com.visa     DEBUG   visa
# 30  2018-10-19 14:49:25,640  qcodes.instrument.base.com.visa     DEBUG   visa
# 31  2018-10-19 14:49:25,642  qcodes.instrument.base.com.visa     DEBUG   visa
# 32  2018-10-19 14:49:25,642  qcodes.instrument.base.com.visa     DEBUG   visa
# 33  2018-10-19 14:49:25,643  qcodes.instrument.base.com.visa     DEBUG   visa
# 34  2018-10-19 14:49:25,643  qcodes.instrument.base.com.visa     DEBUG   visa
# 35  2018-10-19 14:49:25,643  qcodes.instrument.base.com.visa     DEBUG   visa
# 36  2018-10-19 14:49:25,643  qcodes.instrument.base.com.visa     DEBUG   visa
# 37  2018-10-19 14:49:25,657  qcodes.instrument.base.com.visa     DEBUG   visa
# 38  2018-10-19 14:49:25,658  qcodes.instrument.base.com.visa     DEBUG   visa
# 39  2018-10-19 14:49:25,658  qcodes.instrument.base.com.visa     DEBUG   visa
# 40  2018-10-19 14:49:25,658  qcodes.instrument.base.com.visa     DEBUG   visa
#
#      funcName lineno instrument_name  \
# 0     ask_raw    228               x
# 1     ask_raw    230               x
# 2     ask_raw    228               y
# 3     ask_raw    230               y
# 4     ask_raw    228               z
# 5     ask_raw    230               z
# 6     ask_raw    228               x
# 7     ask_raw    230               x
# 8     ask_raw    228               y
# 9     ask_raw    230               y
# 10    ask_raw    228               z
# 11    ask_raw    230               z
# 12    ask_raw    228               x
# 13    ask_raw    230               x
# 14    ask_raw    228               y
# 15    ask_raw    230               y
# 16    ask_raw    228               z
# 17    ask_raw    230               z
# 18    ask_raw    228               z
# 19    ask_raw    230               z
# 20    ask_raw    228               z
# 21    ask_raw    230               z
# 22    ask_raw    228               z
# 23    ask_raw    230               z
# 24    ask_raw    228               z
# 25    ask_raw    230               z
# 26    ask_raw    228               z
# 27    ask_raw    230               z
# 28  write_raw    213               z
# 29  write_raw    213               z
# 30    ask_raw    228               z
# 31    ask_raw    230               z
# 32    ask_raw    228               z
# 33    ask_raw    230               z
# 34    ask_raw    228               z
# 35    ask_raw    230               z
# 36  write_raw    213               z
# 37    ask_raw    228               z
# 38    ask_raw    230               z
# 39    ask_raw    228               z
# 40    ask_raw    230               z
#
#                                         message
# 0             [x(AMI430_VISA)] Querying: STATE?
# 1                  [x(AMI430_VISA)] Response: 2
# 2             [y(AMI430_VISA)] Querying: STATE?
# 3                  [y(AMI430_VISA)] Response: 2
# 4             [z(AMI430_VISA)] Querying: STATE?
# 5                  [z(AMI430_VISA)] Response: 2
# 6         [x(AMI430_VISA)] Querying: FIELD:MAG?
# 7                  [x(AMI430_VISA)] Response: 0
# 8         [y(AMI430_VISA)] Querying: FIELD:MAG?
# 9                  [y(AMI430_VISA)] Response: 0
# 10        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 11                 [z(AMI430_VISA)] Response: 0
# 12        [x(AMI430_VISA)] Querying: FIELD:MAG?
# 13                 [x(AMI430_VISA)] Response: 0
# 14        [y(AMI430_VISA)] Querying: FIELD:MAG?
# 15                 [y(AMI430_VISA)] Response: 0
# 16        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 17                 [z(AMI430_VISA)] Response: 0
# 18             [z(AMI430_VISA)] Querying: COIL?
# 19                 [z(AMI430_VISA)] Response: 1
# 20       [z(AMI430_VISA)] Querying: CURR:LIMIT?
# 21                [z(AMI430_VISA)] Response: 80
# 22               [z(AMI430_VISA)] Querying: QU?
# 23                 [z(AMI430_VISA)] Response: 0
# 24             [z(AMI430_VISA)] Querying: PERS?
# 25                 [z(AMI430_VISA)] Response: 0
# 26            [z(AMI430_VISA)] Querying: STATE?
# 27                 [z(AMI430_VISA)] Response: 2
# 28              [z(AMI430_VISA)] Writing: PAUSE
# 29  [z(AMI430_VISA)] Writing: CONF:FIELD:TARG 1
# 30          [z(AMI430_VISA)] Querying: PS:INST?
# 31             [z(AMI430_VISA)] Response: ERROR
# 32          [z(AMI430_VISA)] Querying: PS:INST?
# 33             [z(AMI430_VISA)] Response: ERROR
# 34               [z(AMI430_VISA)] Querying: PS?
# 35                 [z(AMI430_VISA)] Response: 0
# 36               [z(AMI430_VISA)] Writing: RAMP
# 37            [z(AMI430_VISA)] Querying: STATE?
# 38                 [z(AMI430_VISA)] Response: 2
# 39            [z(AMI430_VISA)] Querying: STATE?
# 40                 [z(AMI430_VISA)] Response: 2

# %%
df2
# Out:
#                     asctime                             name levelname module  \
# 0   2018-10-19 14:49:25,616  qcodes.instrument.base.com.visa     DEBUG   visa
# 1   2018-10-19 14:49:25,617  qcodes.instrument.base.com.visa     DEBUG   visa
# 2   2018-10-19 14:49:25,617  qcodes.instrument.base.com.visa     DEBUG   visa
# 3   2018-10-19 14:49:25,617  qcodes.instrument.base.com.visa     DEBUG   visa
# 4   2018-10-19 14:49:25,617  qcodes.instrument.base.com.visa     DEBUG   visa
# 5   2018-10-19 14:49:25,618  qcodes.instrument.base.com.visa     DEBUG   visa
# 6   2018-10-19 14:49:25,633  qcodes.instrument.base.com.visa     DEBUG   visa
# 7   2018-10-19 14:49:25,633  qcodes.instrument.base.com.visa     DEBUG   visa
# 8   2018-10-19 14:49:25,634  qcodes.instrument.base.com.visa     DEBUG   visa
# 9   2018-10-19 14:49:25,634  qcodes.instrument.base.com.visa     DEBUG   visa
# 10  2018-10-19 14:49:25,634  qcodes.instrument.base.com.visa     DEBUG   visa
# 11  2018-10-19 14:49:25,635  qcodes.instrument.base.com.visa     DEBUG   visa
# 12  2018-10-19 14:49:25,635  qcodes.instrument.base.com.visa     DEBUG   visa
# 13  2018-10-19 14:49:25,635  qcodes.instrument.base.com.visa     DEBUG   visa
# 14  2018-10-19 14:49:25,635  qcodes.instrument.base.com.visa     DEBUG   visa
# 15  2018-10-19 14:49:25,636  qcodes.instrument.base.com.visa     DEBUG   visa
# 16  2018-10-19 14:49:25,636  qcodes.instrument.base.com.visa     DEBUG   visa
# 17  2018-10-19 14:49:25,637  qcodes.instrument.base.com.visa     DEBUG   visa
# 18  2018-10-19 14:49:25,637  qcodes.instrument.base.com.visa     DEBUG   visa
# 19  2018-10-19 14:49:25,638  qcodes.instrument.base.com.visa     DEBUG   visa
# 20  2018-10-19 14:49:25,638  qcodes.instrument.base.com.visa     DEBUG   visa
# 21  2018-10-19 14:49:25,638  qcodes.instrument.base.com.visa     DEBUG   visa
# 22  2018-10-19 14:49:25,638  qcodes.instrument.base.com.visa     DEBUG   visa
# 23  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 24  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 25  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 26  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 27  2018-10-19 14:49:25,639  qcodes.instrument.base.com.visa     DEBUG   visa
# 28  2018-10-19 14:49:25,640  qcodes.instrument.base.com.visa     DEBUG   visa
# 29  2018-10-19 14:49:25,640  qcodes.instrument.base.com.visa     DEBUG   visa
# ..                      ...                              ...       ...    ...
# 52  2018-10-19 14:49:25,703  qcodes.instrument.base.com.visa     DEBUG   visa
# 53  2018-10-19 14:49:25,703  qcodes.instrument.base.com.visa     DEBUG   visa
# 54  2018-10-19 14:49:25,703  qcodes.instrument.base.com.visa     DEBUG   visa
# 55  2018-10-19 14:49:25,704  qcodes.instrument.base.com.visa     DEBUG   visa
# 56  2018-10-19 14:49:25,704  qcodes.instrument.base.com.visa     DEBUG   visa
# 57  2018-10-19 14:49:25,704  qcodes.instrument.base.com.visa     DEBUG   visa
# 58  2018-10-19 14:49:25,705  qcodes.instrument.base.com.visa     DEBUG   visa
# 59  2018-10-19 14:49:25,705  qcodes.instrument.base.com.visa     DEBUG   visa
# 60  2018-10-19 14:49:25,705  qcodes.instrument.base.com.visa     DEBUG   visa
# 61  2018-10-19 14:49:25,706  qcodes.instrument.base.com.visa     DEBUG   visa
# 62  2018-10-19 14:49:25,706  qcodes.instrument.base.com.visa     DEBUG   visa
# 63  2018-10-19 14:49:25,707  qcodes.instrument.base.com.visa     DEBUG   visa
# 64  2018-10-19 14:49:25,707  qcodes.instrument.base.com.visa     DEBUG   visa
# 65  2018-10-19 14:49:25,708  qcodes.instrument.base.com.visa     DEBUG   visa
# 66  2018-10-19 14:49:25,711  qcodes.instrument.base.com.visa     DEBUG   visa
# 67  2018-10-19 14:49:25,711  qcodes.instrument.base.com.visa     DEBUG   visa
# 68  2018-10-19 14:49:25,712  qcodes.instrument.base.com.visa     DEBUG   visa
# 69  2018-10-19 14:49:25,712  qcodes.instrument.base.com.visa     DEBUG   visa
# 70  2018-10-19 14:49:25,712  qcodes.instrument.base.com.visa     DEBUG   visa
# 71  2018-10-19 14:49:25,713  qcodes.instrument.base.com.visa     DEBUG   visa
# 72  2018-10-19 14:49:25,713  qcodes.instrument.base.com.visa     DEBUG   visa
# 73  2018-10-19 14:49:25,713  qcodes.instrument.base.com.visa     DEBUG   visa
# 74  2018-10-19 14:49:25,714  qcodes.instrument.base.com.visa     DEBUG   visa
# 75  2018-10-19 14:49:25,714  qcodes.instrument.base.com.visa     DEBUG   visa
# 76  2018-10-19 14:49:25,714  qcodes.instrument.base.com.visa     DEBUG   visa
# 77  2018-10-19 14:49:25,714  qcodes.instrument.base.com.visa     DEBUG   visa
# 78  2018-10-19 14:49:25,728  qcodes.instrument.base.com.visa     DEBUG   visa
# 79  2018-10-19 14:49:25,728  qcodes.instrument.base.com.visa     DEBUG   visa
# 80  2018-10-19 14:49:25,729  qcodes.instrument.base.com.visa     DEBUG   visa
# 81  2018-10-19 14:49:25,729  qcodes.instrument.base.com.visa     DEBUG   visa
#
#      funcName lineno instrument_name  \
# 0     ask_raw    228               x
# 1     ask_raw    230               x
# 2     ask_raw    228               y
# 3     ask_raw    230               y
# 4     ask_raw    228               z
# 5     ask_raw    230               z
# 6     ask_raw    228               x
# 7     ask_raw    230               x
# 8     ask_raw    228               y
# 9     ask_raw    230               y
# 10    ask_raw    228               z
# 11    ask_raw    230               z
# 12    ask_raw    228               x
# 13    ask_raw    230               x
# 14    ask_raw    228               y
# 15    ask_raw    230               y
# 16    ask_raw    228               z
# 17    ask_raw    230               z
# 18    ask_raw    228               z
# 19    ask_raw    230               z
# 20    ask_raw    228               z
# 21    ask_raw    230               z
# 22    ask_raw    228               z
# 23    ask_raw    230               z
# 24    ask_raw    228               z
# 25    ask_raw    230               z
# 26    ask_raw    228               z
# 27    ask_raw    230               z
# 28  write_raw    213               z
# 29  write_raw    213               z
# ..        ...    ...             ...
# 52    ask_raw    230               z
# 53    ask_raw    228               x
# 54    ask_raw    230               x
# 55    ask_raw    228               y
# 56    ask_raw    230               y
# 57    ask_raw    228               z
# 58    ask_raw    230               z
# 59    ask_raw    228               z
# 60    ask_raw    230               z
# 61    ask_raw    228               z
# 62    ask_raw    230               z
# 63    ask_raw    228               z
# 64    ask_raw    230               z
# 65    ask_raw    228               z
# 66    ask_raw    230               z
# 67    ask_raw    228               z
# 68    ask_raw    230               z
# 69  write_raw    213               z
# 70  write_raw    213               z
# 71    ask_raw    228               z
# 72    ask_raw    230               z
# 73    ask_raw    228               z
# 74    ask_raw    230               z
# 75    ask_raw    228               z
# 76    ask_raw    230               z
# 77  write_raw    213               z
# 78    ask_raw    228               z
# 79    ask_raw    230               z
# 80    ask_raw    228               z
# 81    ask_raw    230               z
#
#                                         message
# 0             [x(AMI430_VISA)] Querying: STATE?
# 1                  [x(AMI430_VISA)] Response: 2
# 2             [y(AMI430_VISA)] Querying: STATE?
# 3                  [y(AMI430_VISA)] Response: 2
# 4             [z(AMI430_VISA)] Querying: STATE?
# 5                  [z(AMI430_VISA)] Response: 2
# 6         [x(AMI430_VISA)] Querying: FIELD:MAG?
# 7                  [x(AMI430_VISA)] Response: 0
# 8         [y(AMI430_VISA)] Querying: FIELD:MAG?
# 9                  [y(AMI430_VISA)] Response: 0
# 10        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 11                 [z(AMI430_VISA)] Response: 0
# 12        [x(AMI430_VISA)] Querying: FIELD:MAG?
# 13                 [x(AMI430_VISA)] Response: 0
# 14        [y(AMI430_VISA)] Querying: FIELD:MAG?
# 15                 [y(AMI430_VISA)] Response: 0
# 16        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 17                 [z(AMI430_VISA)] Response: 0
# 18             [z(AMI430_VISA)] Querying: COIL?
# 19                 [z(AMI430_VISA)] Response: 1
# 20       [z(AMI430_VISA)] Querying: CURR:LIMIT?
# 21                [z(AMI430_VISA)] Response: 80
# 22               [z(AMI430_VISA)] Querying: QU?
# 23                 [z(AMI430_VISA)] Response: 0
# 24             [z(AMI430_VISA)] Querying: PERS?
# 25                 [z(AMI430_VISA)] Response: 0
# 26            [z(AMI430_VISA)] Querying: STATE?
# 27                 [z(AMI430_VISA)] Response: 2
# 28              [z(AMI430_VISA)] Writing: PAUSE
# 29  [z(AMI430_VISA)] Writing: CONF:FIELD:TARG 1
# ..                                          ...
# 52                 [z(AMI430_VISA)] Response: 1
# 53        [x(AMI430_VISA)] Querying: FIELD:MAG?
# 54                 [x(AMI430_VISA)] Response: 0
# 55        [y(AMI430_VISA)] Querying: FIELD:MAG?
# 56                 [y(AMI430_VISA)] Response: 0
# 57        [z(AMI430_VISA)] Querying: FIELD:MAG?
# 58                 [z(AMI430_VISA)] Response: 1
# 59             [z(AMI430_VISA)] Querying: COIL?
# 60                 [z(AMI430_VISA)] Response: 1
# 61       [z(AMI430_VISA)] Querying: CURR:LIMIT?
# 62                [z(AMI430_VISA)] Response: 80
# 63               [z(AMI430_VISA)] Querying: QU?
# 64                 [z(AMI430_VISA)] Response: 0
# 65             [z(AMI430_VISA)] Querying: PERS?
# 66                 [z(AMI430_VISA)] Response: 0
# 67            [z(AMI430_VISA)] Querying: STATE?
# 68                 [z(AMI430_VISA)] Response: 2
# 69              [z(AMI430_VISA)] Writing: PAUSE
# 70  [z(AMI430_VISA)] Writing: CONF:FIELD:TARG 2
# 71          [z(AMI430_VISA)] Querying: PS:INST?
# 72             [z(AMI430_VISA)] Response: ERROR
# 73          [z(AMI430_VISA)] Querying: PS:INST?
# 74             [z(AMI430_VISA)] Response: ERROR
# 75               [z(AMI430_VISA)] Querying: PS?
# 76                 [z(AMI430_VISA)] Response: 0
# 77               [z(AMI430_VISA)] Writing: RAMP
# 78            [z(AMI430_VISA)] Querying: STATE?
# 79                 [z(AMI430_VISA)] Response: 2
# 80            [z(AMI430_VISA)] Querying: STATE?
# 81                 [z(AMI430_VISA)] Response: 2
#
# [82 rows x 8 columns]

# %% [markdown]
# You can of course combine the context managers like this:

# %%
with logger.console_level(logging.WARN):
    driver.cartesian((0, 0, 0))
    with logger.capture_dataframe(level='DEBUG') as (handler, get_dataframe):
        with logger.filter_instrument(mag_x, handler=handler):
            driver.cartesian((0, 0, 1))
            df = get_dataframe()
df
# Out:
#                    asctime                             name levelname module  \
# 0  2018-10-19 14:49:26,142  qcodes.instrument.base.com.visa     DEBUG   visa
# 1  2018-10-19 14:49:26,143  qcodes.instrument.base.com.visa     DEBUG   visa
# 2  2018-10-19 14:49:26,145  qcodes.instrument.base.com.visa     DEBUG   visa
# 3  2018-10-19 14:49:26,146  qcodes.instrument.base.com.visa     DEBUG   visa
# 4  2018-10-19 14:49:26,147  qcodes.instrument.base.com.visa     DEBUG   visa
# 5  2018-10-19 14:49:26,148  qcodes.instrument.base.com.visa     DEBUG   visa
#
#   funcName lineno instrument_name                                message
# 0  ask_raw    228               x      [x(AMI430_VISA)] Querying: STATE?
# 1  ask_raw    230               x           [x(AMI430_VISA)] Response: 2
# 2  ask_raw    228               x  [x(AMI430_VISA)] Querying: FIELD:MAG?
# 3  ask_raw    230               x           [x(AMI430_VISA)] Response: 0
# 4  ask_raw    228               x  [x(AMI430_VISA)] Querying: FIELD:MAG?
# 5  ask_raw    230               x           [x(AMI430_VISA)] Response: 0

# %% [markdown]
# For an analysis of the timestamps please also refer to the log analysis example notebook ([online](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/logging/logfile_parsing.ipynb), [offline](logfile_parsing_ipynb)).
