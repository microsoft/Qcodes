# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import numpy as np  
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data_set import *

# %%
x = ParamSpec("x")
y = ParamSpec("y")
s = ParamSpec("s")
z = ParamSpec("z")
dataset = DataSet("data_set", [x,y,s,z])
# dead simple 2d loop x,y are know to begin with
x_sweep = list(range(1,4))
y_sweep = list(range(1,6))

# scenario 1:
# simply add the data to paramspec

x.data = x_sweep
y.data = y_sweep

# why not then specfiy the setpoint relations?
# we measure s for every x
s.setpoints = x.id
# and y for every x
y.setpoints = x.id 
# and z for every x,y
z.setpoints  = y.id

for x_val in x.data:
    # set x
    dataset.add_result(s=(x_val - 3 * np.sin(x_val)))
    for y_val in y.data:
        #time.sleep(0.001)
        # set y
        # measure values:
        dataset.add_result(z=(x_val + y_val))
        #dataset.to_array("z")

# %%
dataset

# %%
plt.pcolormesh(dataset.to_array("z"))

# %%
def plot1d(name):
    param = dataset.get_parameter(name)
    setpoints = dataset.get_param_setpoints(name)
    plt.plot(setpoints[0].data,param.data)

# %%
plot1d("s")

# %% [markdown]
# # Live streaming data

# %%
from threading import Thread
from queue import Queue
from itertools import count

# %%
class Listener(Thread):
    def __init__(self, shape, q):
        self.c = count(0)
        self.q = q
        self.z_arr = np.ma.masked_invalid(np.empty(shape)* np.nan)
        self.stop = False
        self.fig, self.ax = plt.subplots()
        super().__init__()
    
    def run(self):
        while True:
            msg = self.q.get()
            if msg =="DONE":
                break
            else:
                print(msg)
                self.z_arr.flat[msg[0]-1] = msg[1]
            
            if next(self.c) % 200 == 0:
                self.ax.pcolormesh(self.z_arr)
                self.fig.canvas.draw()

# %%
x = ParamSpec("x")
y = ParamSpec("y")
s = ParamSpec("s")
z = ParamSpec("z")
dataset = DataSet("data_set", [x,y,s,z])
# dead simple 2d loop x,y are know to begin with
x_sweep = list(range(1,40))
y_sweep = list(range(1,600))

# scenario 1:
# simply add the data to paramspec


y.data = y_sweep

# why not then specfiy the setpoint relations?
# we measure s for every x
s.setpoints = x.id
# and y for every x
y.setpoints = x.id 
# and z for every x,y
z.setpoints  = y.id

# %%
q = Queue()
# streamer
t = Listener(dataset.guess_shape("z"), q)
t.start()
# Out:
# /Users/unga/.pyenv/versions/miniconda3-latest/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in multiply
#   """
# <img src="data:image/png;base64,..." width="640">

# %%
import time

# %%
for x_val in x_sweep:
    # set x
    dataset.add_result(x=x_val )
    dataset.add_result(s=(x_val - 3 * np.sin(x_val)))
    for y_val in y.data:
        nest
        # set y
        # measure values:
        dataset.add_result(z=(x_val + y_val))
        # q.put([len(dataset.get_data("z")), x_val + y_val])

# %%
q.put('DONE')

# %%
t.join()

# %%
dataset
# Out:
# data_set
# --------
# x:39
# y:599
# s:39
# z:23361

# %%
plt.pcolormesh(dataset.to_array("z"))
