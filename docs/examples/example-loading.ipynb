# %%
import qcodes as qc
# Out:
# pyqtgraph plotting not supported, try "from qcodes.plots.pyqtgraph import QtPlot" to see the full error

# %%
qc.experiments()
# Out:
# [sweep gate #1@./experiments.db
#  ------------------------------
#  a - INTEGER
#  b - INTEGER
#  c - array]

# %%
exp = qc.load_last_experiment()

# %%
exp
# Out:
# majorana-qbuit#flying brdige#1@./experiments.db
# -----------------------------------------------
# 1-sweep gate-1-a,b,c-1
# 2-sweep gate-2-None-0
# 3-test-3-x,y-100
# 4-test-4-x,y-100

# %%
qc.load_by_counter(3, 1)
# Out:
# test #3@./experiments.db
# ------------------------
# x - number
# y - number

# %%
exp.data_set(3)
# Out:
# test #3@./experiments.db
# ------------------------
# x - number
# y - number

# %%
qc.load_experiment_by_name('majorana-qbuit')
# Out:
# majorana-qbuit#flying brdige#1@./experiments.db
# -----------------------------------------------
# 1-sweep gate-1-a,b,c-1
# 2-sweep gate-2-None-0
# 3-test-3-x,y-100
# 4-test-4-x,y-100

# %%
qc.new_experiment('majorana-qbuit', sample_name="test")
# Out:
# majorana-qbuit#test#2@./experiments.db
# --------------------------------------

# %%
qc.load_experiment_by_name('majorana-qbuit')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-86bb548ff470> in <module>()
# ----> 1 qc.load_experiment_by_name('majorana-qbuit')
#
# ~/src/Qcodes/qcodes/dataset/experiment_container.py in load_experiment_by_name(name, sample)
#     216             _repr.append(s)
#     217         _repr = "\n".join(_repr)
# --> 218         raise ValueError(f"Many experiments machign your request found {_repr}")
#     219     else:
#     220         e.id = rows[0]['exp_id']
#
# ValueError: Many experiments machign your request found exp_id:1 (majorana-qbuit-flying brdige) started at(1499780130.8274162)
# exp_id:2 (majorana-qbuit-test) started at(1499780146.684204)

# %%
qc.load_experiment_by_name('majorana-qbuit', "test")
# Out:
# majorana-qbuit#test#2@./experiments.db
# --------------------------------------
