# %% [markdown]
# # Qcodes example with Signal Hound USB-SA124B ParameterWithSetpoints

# %%
import qcodes as qc

# %%
from qcodes.instrument_drivers.signal_hound.USB_SA124B import SignalHound_USB_SA124B
from qcodes.dataset.measurements import Measurement
from qcodes.dataset.plotting import plot_by_id

# %%
mysa = SignalHound_USB_SA124B('mysa', dll_path='C:\\Program Files\\Signal Hound\\Spike\\sa_api.dll')
# Out:
# Connected to: Signal Hound sa124B (serial:17172185, firmware:Version 3.13) in 5.93s

# %%
mysa.get_idn()
# Out:
# {'vendor': 'Signal Hound',
#  'model': 'sa124B',
#  'serial': '17172185',
#  'firmware': 'Version 3.13'}

# %%
mysa.frequency(2e9)
mysa.span(0.5e6)

# %%
mysa.avg(1)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)
with meas.run() as datasaver:
    datasaver.add_result((mysa.frequency_axis, mysa.frequency_axis.get()),
                         (mysa.freq_sweep, mysa.freq_sweep.get(),))
    
    dataid = datasaver.run_id
plot_by_id(dataid)
# Out:
# Starting experimental run with id: 309
# ([<matplotlib.axes._subplots.AxesSubplot at 0x1da84b9e4a8>], [None])

# %%
mysa.avg(10)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)
with meas.run() as datasaver:
    datasaver.add_result((mysa.frequency_axis, mysa.frequency_axis.get()),
                         (mysa.freq_sweep, mysa.freq_sweep.get(),))
    
    dataid = datasaver.run_id
plot_by_id(dataid)
# Out:
# Starting experimental run with id: 310
# ([<matplotlib.axes._subplots.AxesSubplot at 0x1da84cb27b8>], [None])

# %%
mysa.avg(100)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)
with meas.run() as datasaver:
    datasaver.add_result((mysa.frequency_axis, mysa.frequency_axis.get()),
                         (mysa.freq_sweep, mysa.freq_sweep.get(),))
    
    dataid = datasaver.run_id
plot_by_id(dataid)
# Out:
# Starting experimental run with id: 311
# ([<matplotlib.axes._subplots.AxesSubplot at 0x1da84cb96a0>], [None])

# %%
mysa.frequency(3e9)
mysa.span(1e6)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)
with meas.run() as datasaver:
    datasaver.add_result((mysa.frequency_axis, mysa.frequency_axis.get()),
                         (mysa.freq_sweep, mysa.freq_sweep.get(),))
    dataid = datasaver.run_id
plot_by_id(dataid)
# Out:
# Starting experimental run with id: 312
# ([<matplotlib.axes._subplots.AxesSubplot at 0x1da8607e2e8>], [None])

# %%
mysa.frequency(3e9)
mysa.span(1e8)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)
with meas.run() as datasaver:
    datasaver.add_result((mysa.frequency_axis, mysa.frequency_axis.get()),
                         (mysa.freq_sweep, mysa.freq_sweep.get(),))
    dataid = datasaver.run_id
plot_by_id(dataid)
# Out:
# Starting experimental run with id: 313
# During call of saInitiate the followingWarning: saBandwidthClamped was raised
# ([<matplotlib.axes._subplots.AxesSubplot at 0x1da86131198>], [None])

# %%
mysa.close()
