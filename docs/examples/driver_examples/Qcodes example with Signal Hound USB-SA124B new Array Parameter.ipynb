# %% [markdown]
# # Qcodes example with Signal Hound USB-SA124B new Array Parameter

# %%
import qcodes as qc

# %%
from qcodes.instrument_drivers.signal_hound.USB_SA124B import SignalHound_USB_SA124B
from qcodes.dataset.measurements import Measurement
from qcodes.dataset.plotting import plot_by_id

# %%
mysa = SignalHound_USB_SA124B('mysa', dll_path='C:\\Program Files\\Signal Hound\\Spike\\sa_api.dll')
# Out:
# Connected to: Signal Hound sa124B (serial:17172185, firmware:Version 3.13) in 5.92s

# %%
mysa.get_idn()
# Out:
# {'vendor': 'Signal Hound',
#  'model': 'sa124B',
#  'serial': '17172185',
#  'firmware': 'Version 3.13'}

# %%
mysa.freq_sweep()
# Out:
# 1054
# array([-91.55989838, -98.06058502, -95.64240265, ..., -91.06426239,
#        -91.20920563, -91.69102478])

# %%
mysa.frequency(2e9)
mysa.span(0.5e6)

# %%
mysa.avg(1)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)  # register the first independent parameter
with meas.run() as datasaver:
    datasaver.add_result((mysa.freq_sweep, mysa.freq_sweep.get(),))
    
    dataid = datasaver.run_id  # convenient to have for plotting
plot_by_id(dataid)
# Out:
# Starting experimental run with id: 937
# 2107
# ([<matplotlib.axes._subplots.AxesSubplot at 0x15228190358>], [None])

# %%
mysa.avg(10)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)  # register the first independent parameter
with meas.run() as datasaver:
    datasaver.add_result((mysa.freq_sweep, mysa.freq_sweep.get(),))
    
    dataid = datasaver.run_id  # convenient to have for plotting
plot_by_id(dataid)
# Out:
# Starting experimental run with id: 938
# 2107
# ([<matplotlib.axes._subplots.AxesSubplot at 0x152281a7c50>], [None])

# %%
mysa.avg(100)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)  # register the first independent parameter
with meas.run() as datasaver:
    datasaver.add_result((mysa.freq_sweep, mysa.freq_sweep.get(),))
    
    dataid = datasaver.run_id  # convenient to have for plotting
plot_by_id(dataid)
# Out:
# Starting experimental run with id: 939
# 2107
# ([<matplotlib.axes._subplots.AxesSubplot at 0x152281f2278>], [None])

# %%
mysa.frequency(3e9)
mysa.span(1e6)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)  # register the first independent parameter
with meas.run() as datasaver:
    datasaver.add_result((mysa.freq_sweep, mysa.freq_sweep.get(),))
    dataid = datasaver.run_id  # convenient to have for plotting
plot_by_id(dataid)
# Out:
# Starting experimental run with id: 940
# 4215
# ([<matplotlib.axes._subplots.AxesSubplot at 0x1522960fcc0>], [None])

# %%
mysa.frequency(3e9)
mysa.span(1e8)
meas = Measurement()
meas.register_parameter(mysa.freq_sweep)  # register the first independent parameter
with meas.run() as datasaver:
    datasaver.add_result((mysa.freq_sweep, mysa.freq_sweep.get(),))
    
    dataid = datasaver.run_id  # convenient to have for plotting
plot_by_id(dataid)
# Out:
# During call of saInitiate the followingWarning: saBandwidthClamped was raised
# Starting experimental run with id: 941
# 52500
# ([<matplotlib.axes._subplots.AxesSubplot at 0x1522a614ac8>], [None])

# %%
mysa.close()
